# %%
def invert(dictWord):
    invDict = {}
    for word in dictWord:
        invDict[dictWord[word]] = word
    return invDict

# %%
dictWord = {"A":"abcde", "B":"fghij", "C":"klmno"}
invert(dictWord)
# Out:
# {'abcde': 'A', 'fghij': 'B', 'klmno': 'C'}

# %%
def percentage(marks, total):
    try:
        percent = (marks/total) * 100
    except ValueError:
        print('ValueError')
    except TypeError:
        print('TypeError')
    except ZeroDivisionError:
        print('ZeroDivisionError')
    except:
        print('Any other Error')
    else:
        print(percent)
    finally:
        print('Function percentage completed')

# %%
percentage('150.0', '200.0')
# Out:
# TypeError
# Function percentage completed

# %%
a = 20
def test():
    global a
    b = 30
    a = 40
    print('Inside function test : a = ', a)
    print('Inside function test : b = ', b)
test()
print('Outside function test : a = ', a)
print('Outside function test : b = ', b)
# Out:
# Inside function test : a =  40
# Inside function test : b =  30
# Outside function test : a =  40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c84afbc48776> in <module>
#       8 test()
#       9 print('Outside function test : a = ', a)
# ---> 10 print('Outside function test : b = ', b)
#
# NameError: name 'b' is not defined

# %%
z=0
def demo():
    z = z+1
demo()
print(z)
# Out:
# 1
# 0

# %%
a = 4
def f():
    a=5
    def g():
        nonlocal a
        a = 10
        print('inside function g,', 'a = ', a)
        def h():
            nonlocal a
            a = 20
            print('inside function h,', 'a = ', a)
        h()
    g()
    print('inside function f,', 'a = ', a)
f()
print(a)
# Out:
# inside function g, a =  10
# inside function h, a =  20
# inside function f, a =  20
# 4

# %%
def pattern(n):
    for i in range(1,n+1):
# Out:
#   File "<ipython-input-26-362b14338414>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def decode(s):
    s1 = ''
    alpha_str = "abcdefghijklmnopqrstuvwxyz"
    alpha_list = list(alpha_str)
    for i in s:
        s1 += alpha_list[alpha_list.index(i)-3]
    return s1

# %%
decode('xyz')
# Out:
# 'uvw'

# %%
def pattern1(n):
    for i in range(1,n+1):
        if i in range(2,n):
            print('*'+ ' '*(3*n-4) + '*')
        else:
            print('*  '*n)
pattern1(7)
# Out:
# *  *
# *  *

# %%
def pattern2(n):
    for i in range(1, n+1):
        s1 = ''
        for j in range(-(n-1),n):
            if i in range(2, n+1):
                if abs(j) == abs(i-n):
                    s1+='*  '
                else:
                    s1 += '   '
            else:
                s1 += '*  '
        print(s1)
            
pattern2(7)
# Out:
# *  *  *  *  *  *  *  *  *  *  *  *  *
#    *                             *
#       *                       *
#          *                 *
#             *           *
#                *     *
#                   *

# %%
def cumulative(lst, cumulativeLst = [], i=0):
    if i < len(lst):
        sum_i = sum(lst[0:i+1])
        cumulativeLst.append(sum_i)
        cumulative(lst, cumulativeLst, i+1)
    return cumulativeLst

# %%
lst=[1,2,3,4,5]
cumulative(lst)
# Out:
# [1, 3, 6, 10, 15]

# %%
def cumulative(lst, cumulativeLst)

# %%
f = open('research.txt','w')
f.write("My name is python programming khan python programming")
# Out:
# 53

# %%
f.close()

# %%
def func(file_name):
    f = open(file_name,'r')
    line = f.readline()
    lst = line.split()
    word_count = len(lst)
    word_start_cons = 0
    for word in lst:
        if word[0] not in ['a','e','i','o','u']:
            word_start_cons += 1
    phrase_count = line.count('python programming')
    return (word_count, word_start_cons, phrase_count)

# %%
func('research.txt')
# Out:
# (8, 7, 2)

# %%
class Date(day, month, year):
# Out:
#   File "<ipython-input-190-40f9d4fb3d71>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def copyLst(lst):

    if lst == []:

        return []

    else:

        lst1 = copyLst(lst[1:]) + [lst[0]]

        return lst1

 

lst = [10, 20]

lst1 = copyLst(lst)

print(lst1)
# Out:
# [20, 10]

# %%
def copyLst(lst, lst1 = [], i = 0):

    if lst == []:

        return []

    if i == len(lst):

        return lst1

    else:

        lst1.append(lst[i])

        lst1 = copyLst(lst[1:]) + [lst[0]]

        return lst1

lst = [10, 20]

lst1 = copyLst(lst)

print(lst1)
# Out:
# [20, 10]

# %%
def copyLst(lst, lst1 = [], i = 0):

    if len(lst) == 0:

        return lst1

    else:

        if i != len(lst):

            lst1.append(lst[i])

            copyLst(lst[1:], lst1, i+1)

            return lst1

        else:

            return lst1

lst = [10, 20, 30]

lst1 = copyLst(lst)

print(lst1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-195-7e6596046c6a> in <module>
#      21 lst = [10, 20, 30]
#      22
# ---> 23 lst1 = copyLst(lst)
#      24
#      25 print(lst1)
#
# <ipython-input-195-7e6596046c6a> in copyLst(lst, lst1, i)
#      11             lst1.append(lst[i])
#      12
# ---> 13             copyLst(lst[1:], lst1, i+1)
#      14
#      15             return lst1
#
# <ipython-input-195-7e6596046c6a> in copyLst(lst, lst1, i)
#      11             lst1.append(lst[i])
#      12
# ---> 13             copyLst(lst[1:], lst1, i+1)
#      14
#      15             return lst1
#
# <ipython-input-195-7e6596046c6a> in copyLst(lst, lst1, i)
#       9         if i != len(lst):
#      10
# ---> 11             lst1.append(lst[i])
#      12
#      13             copyLst(lst[1:], lst1, i+1)
#
# IndexError: list index out of range

# %%
import sys
class Date:
    def __init__(self, day, month, year):
        if not((type(day) == int) and (type(month) == int) and \
           type(year) == int):
            print('Enter correct date type')
            sys.exit()
        if month>0 and month<=12:
            self.month = month
        else: 
            print('Invalid value for month')
            sys.exit()
        if year>=1900:
            self.year = year
        else:
            print('Invalid value for year')
            sys.exit()
        self.day = self.checkday(day)
    def checkday(self, day):
        currentyear = self.current_year()
        if day>0 and day<=currentyear[self.month-1] :
            return day
        else:
            print('Invalid date value')
            sys.exit()
    def __str__(self):
        if self.day<10:
            day = '0' + str(self.day)
        else:
            day = str(self.day)
        if self.month<10:
            month = '0' + str(self.month)
        else:
            month = str(self.month)
        date = day + '-' + month + '-' + str(self.year)
        return date
    def current_year(self):
        if self.year%400==0 or (self.year%100!=0 and self.year%4==0):
            currentyear = [31,29,31,30,31,30,31,31,30,31,30,31]
        else:
            currentyear = [31,28,31,30,31,30,31,31,30,31,30,31]
        return currentyear
    def next_date(self):
        currentyear = self.current_year()
        if self.day == currentyear[self.month-1]:
            day = 1
            if self.month == 12:
                month = 1
                year = self.year+1
            else:
                month = self.month+1
                year = self.year
        else:
            day = self.day+1
            month = self.month
            year = self.year
        return str(day) + '-' + str(month) + '-' + str(year)

# %%
d1 = Date(31,12,1992)

# %%
print(d1)
# Out:
# 31-12-1992

# %%
d1.next_date()
# Out:
# '1-1-1993'

# %%
def bubblestep(lst, k,m = -2):
    if m == -2:
        m = len(lst)-1
    if m == k:
        return lst
    if lst[m]<lst[m-1]:
        lst[m], lst[m-1] = lst[m-1], lst[m]
        return bubblestep(lst, k, m-1)
    else:
        return bubblestep(lst, k, m-1)

# %%
def bubblesort(lst, i=0):
    if i == len(lst):
        return lst
    else:
        lst = bubblestep(lst, i)
        return bubblesort(lst, i+1)

# %%
lst = [36,17,40,8,18,5,35,12,17,30,13]
bubblesort(lst)
# Out:
# [5, 8, 12, 13, 17, 18, 30, 35, 36, 40]

# %%
dict1 = {'a':[1,2],'b':[3],'c':[5,6]} 
{key:value for key,value in dict1.items() if len(value)>1}
# Out:
# {'a': [1, 2], 'c': [5, 6]}

# %%
def rem(lst1,lst2=[],n=0):
    if n==len(lst1):
        return lst2
    else:
        if lst1[n] not in lst2:
            lst2.append(lst1[n])
        return rem(lst1,lst2,n+1)

# %%
lst = [1,2,4,4,5,7,7,7,8,8,9,7]
# Out:
# [1, 2, 4, 4, 5, 7, 7, 7, 8, 8, 9, 7, 7, 7, 7]

# %%
def dup(a, i = 0, flag = False):
    if(i >= len(a)-1):
        if flag == True and len(a)==1:
            a = []
            return a
        else:
            return a
        
    elif(a[i] == a[i+1]):
        a.pop(i)
        i -= 1
        flag = True
    elif(flag):
        a.pop(i)
        i -= 1
        flag = False
    return dup(a, i+1, flag)

a = [7, 7, 7,2]
print(dup(a))
# Out:
# [2]

# %%
def rem(a, value):
    if a[i]==a[i+1]:

# %%
def least_element(lis, i, min_i):
    if i==len(lis):
        return min_i
    if lis[i]<=lis[min_i]:
        return least_element(lis, i+1, i)
    else:
        return least_element(lis, i+1, min_i)

# %%
def selectionsort(lis, i = 0):
    if i < len(lis)-1:
        li = least_element(lis, i, i)
        lis[i], lis[li] = lis[li], lis[i]
        selectionsort(lis, i+1)

# %%
lis = [1,2,3,6,7,5,4,0,17,9]
selectionsort(lis)
lis
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 9, 17]

# %%
def swap(lis, index):
    if lis[index]<lis[index-1] and index>0:
        lis[index], lis[index-1] = lis[index-1], lis[index]
        swap(lis, index-1)
    return

# %%
def insertionsort(lis, i = 1):
    if i<len(lis):
        swap(lis, i)
        insertionsort(lis, i+1)
    return

# %%
lis = [1,2,3,6,7,5,4,0,17,9]
insertionsort(lis)
lis
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 9, 17]

# %%
def cumul(lis, i=1):
    if i<len(lis):
        lis[i]+=lis[i-1]
        cumul(lis,i+1)
    return 
lis = [1,2,3,4]

# %%
cumul(lis)
lis
# Out:
# [1, 3, 6, 10]
